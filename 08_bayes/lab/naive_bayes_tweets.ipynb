# %% [markdown]
# ## Tweet Sentiment Analysis
#
# Create a twitter classifier with naive bayes and check the sentiment for a keyword of your choice.
# Train your classifier with the "tweet_training.csv" file
#
# Sentiment is described as "polarity," where:
#
# - "0" = negative
# - "4" = positive

# %%
import pandas as pd
import numpy as np

# %%
tweets = pd.read_csv('/home/vagrant/notebooks/fall_2014_lessons/datasets/tweet_training.csv', delimiter=';', index_col='id')

# %%
tweets.head()
# Out:
#             polarity                                              tweet
# id
# 1467933112         0  the angel is going to miss the athlete this we...
# 2323395086         0  It looks as though Shaq is getting traded to C...
# 1467968979         0     @clarianne APRIL 9TH ISN'T COMING SOON ENOUGH
# 1990283756         0  drinking a McDonalds coffee and not understand...
# 1988884918         0  So dissapointed Taylor Swift doesnt have a Twi...

# %%
tweets
# Out:
#             polarity                                              tweet
# id
# 1467933112         0  the angel is going to miss the athlete this we...
# 2323395086         0  It looks as though Shaq is getting traded to C...
# 1467968979         0     @clarianne APRIL 9TH ISN'T COMING SOON ENOUGH
# 1990283756         0  drinking a McDonalds coffee and not understand...
# 1988884918         0  So dissapointed Taylor Swift doesnt have a Twi...
# 1467984364         0  Wishes I was on the Spring Fling Tour with Daw...
# 1964951623         0  got a sniffle, got the kids and hubby just lef...
# 1881133744         0  i've only been in sydney for 3 hrs but I miss ...
# 1753802024         0                       xboxtweet not working again
# 1980497384         0        R.I.P to lebron/kobe puppet commercials...
# 1755405128         0  Allergies sucks sometimes. Theres a super ador...
# 1966205498         0                               has a broken iphone
# 2206224118         0  Line at McDonalds was too long so I can't get ...
# 1687790990         0  @stephnewby there is a virus going around  con...
# 1963812485         0                               I scratched my iPod
# 1467844505         0              I don't understand... I really don't
# 2258491381         0  @Rove1974 @Pink is our hero too! Love her! Wan...
# 1468039375         0  I hate the fact that I'm genuinely excited abo...
# 2212063772         0  Tula's sick! Nausious, Nasal congestion, heada...
# 1557163971         0                           Hayfever time  not good!
# 1975133437         0  I wish diversity was like one of those musicia...
# 1932575931         0  Oh No - the Cavs lost game 4  Cavs are 1 loss ...
# 1467899025         0  still sick. feeling a bit better, got some new...
# 2324113552         0  worked on 5 bone marrow cases today! All + for...
# 1468042132         0                          It was a sleepless night
# 1467985185         0             @d_castillo ugh, that's disconcerting
# 1980282216         0  forgot about my english coursework &amp; my ip...
# 2179698078         0            @TweetRamona too bad it's in seattle..
# 1467985259         0                     MY TWEETS ARENT GOING THROUGH
# 2299794306         0  @SeattleRealEst8 439 calories; 28 grams of fat...
# ...              ...                                                ...
# 2194433506         0  I'm tweetless without miPhone   can't wait for...
# 1978986441         0  after seeing Ronan's latest update : I wish I ...
# 1467912100         0  @carolrainbow no Internet at home, have to dri...
# 1467872759         0  im lonely  keep me company! 22 female, california
# 1932409653         0             Damn the cavs lost I lost sum chippaz
# 1982476349         0  Can't finish my damn homework. Fifty more ques...
# 1467858627         0  Just woke up an already have written some e-ma...
# 2199414669         0        Got a fever, and this ain't the disco kind
# 2013743788         0  @leehopkins ok you guys are just too adorable!...
# 2241033723         0  I really want an iPhone, but I have to pay a f...
# 1795305046         0  @michelletripp Don't be too bummed. Saw it @ I...
# 1467910986         0  Keeping my fingers crossed for my buddy    He ...
# 1468038099         0  @sudam08  yes, someone hasn't been reading my ...
# 2053385413         0  I miss him so much  sosososo much. I wanna be ...
# 2000663077         0  Just waking up feeling really tired. Does hayf...
# 1467879203         0  I just saw that they found that Tracy girl in ...
# 2057515232         0    watching uruguay-brazil.. we need a miracle...
# 1754305167         0  @kevinprince I couldn't buy any '#openhacklond...
# 2209465938         0  @simondoggett I would like to install iphone 3...
# 1880171965         0  Just realised I have @hueyyei 's psp in my bag...
# 2214025188         0  I hope Microsoft have fixed #xboxlive #marketp...
# 1467986976         0  @georgeruiz Unfortunately one of those moments...
# 1752634162         0  @BleuMuze  Hit up gameworks and a movie in dow...
# 1467871661         0  I miss you twitter. My phone broke, now I'm us...
# 2071726448         0  @iLoveLyci lol i said the CAVS deserve to be i...
# 1468049681         0  A king sized bed is nice but sad and lonely wi...
# 2195475499         0  @breannalovesjb hurry up home!!!!! im dying wi...
# 1996172176         0  @jordanhowell lol only a PSP, had a game boy b...
# 2016105580         4  Good morning everyone!  It is such a beautiful...
# 2186977170         4  hey guess was @magicmanil the Lakers won and K...
#
# [2034 rows x 2 columns]

# %%
tweet1 = "@DataDAVE thanks for the awesome twitter dataset!!"
tweet2 = "I just don't understand lasso!??!"

# %%
from sklearn.cross_validation import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer(ngram_range=(1,2))

# %%
vectorizer.fit(tweets)
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/core/fromnumeric.py:2499: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# CountVectorizer(analyzer=u'word', binary=False, charset=None,
#         charset_error=None, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
vectorizer.get_feature_names()
# Out:
# [u'polarity', u'tweet']

# %%
X = vectorizer.fit_transform(tweets.tweet)

# %%
Y = (tweets.polarity == 4).values.astype(np.int)

# %%
from sklearn.cross_validation import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, Y)

# %%
def accuracy_report(_clf):
    print "Accuracy: %0.2f%%" % (100 * _clf.score(xtest, ytest))

    #Print the accuracy on the test and training dataset
    training_accuracy = _clf.score(xtrain, ytrain)
    test_accuracy = _clf.score(xtest, ytest)

    print "Accuracy on training data: %0.2f" % (training_accuracy)
    
# a function to run some tests
def AnalyzeReview(testquote):
    print "\""  + testquote + "\" is judged by clasifier to be..."
    testquote = vectorizer.transform([testquote])

    if (clf.predict(testquote)[0] == 1):
        print "... a positive tweet."
    else:
        print "... a negative tweet."
    return(clf.predict(testquote)[0])

# %%
from sklearn.naive_bayes import MultinomialNB

print "MultinomialNB:"
clf = MultinomialNB().fit(xtrain, ytrain)
accuracy_report(clf)
# Out:
# MultinomialNB:
# Accuracy: 84.68%
# Accuracy on training data: 1.00

# %%
from sklearn.naive_bayes import BernoulliNB
print "BernoulliNB:"
clf = BernoulliNB().fit(xtrain, ytrain)
accuracy_report(clf)
# Out:
# BernoulliNB:
# Accuracy: 71.91%
# Accuracy on training data: 0.81

# %%
from sklearn.linear_model import LogisticRegression
print "Logistic Regression:"
clf = LogisticRegression().fit(xtrain, ytrain)
accuracy_report(clf)
# Out:
# Logistic Regression:
# Accuracy: 82.51%
# Accuracy on training data: 1.00

# %%
AnalyzeReview(tweet1)
# Out:
# "@DataDAVE thanks for the awesome twitter dataset!!" is judged by clasifier to be...
# ... a positive tweet.
# 1

# %%
AnalyzeReview(tweet2)
# Out:
# "I just don't understand lasso!??!" is judged by clasifier to be...
# ... a negative tweet.
# 0

# %%
new_tweets = tweets

# %%
new_tweets.tweet = new_tweets.tweet

# %%
for i, tweet in enumerate(tweets.tweet):
    new_tweets.tweet.values[i] = tweets.tweet.values[i].replace(/.{1,3}*\s/,'')
# Out:
#   File "<ipython-input-47-9287d7c2630d>", line 2
#     new_tweets.tweet.values[i] = tweets.tweet.values[i].replace(/.{1,3}*\s/,'')
#                                                                 ^
# SyntaxError: invalid syntax

# %%
new_tweets
# Out:
#             polarity                                              tweet
# id
# 1467933112         0  the angel is going to miss the athlete this we...
# 2323395086         0  It looks as though Shaq is getting traded to C...
# 1467968979         0     @clarianne APRIL 9TH ISN'T COMING SOON ENOUGH
# 1990283756         0  drinking a McDonalds coffee and not understand...
# 1988884918         0  So dissapointed Taylor Swift doesnt have a Twi...
# 1467984364         0  Wishes I was on the Spring Fling Tour with Daw...
# 1964951623         0  got a sniffle, got the kids and hubby just lef...
# 1881133744         0  i've only been in sydney for 3 hrs but I miss ...
# 1753802024         0                       xboxtweet not working again
# 1980497384         0        R.I.P to lebron/kobe puppet commercials...
# 1755405128         0  Allergies sucks sometimes. Theres a super ador...
# 1966205498         0                               has a broken iphone
# 2206224118         0  Line at McDonalds was too long so I can't get ...
# 1687790990         0  @stephnewby there is a virus going around  con...
# 1963812485         0                               I scratched my iPod
# 1467844505         0              I don't understand... I really don't
# 2258491381         0  @Rove1974 @Pink is our hero too! Love her! Wan...
# 1468039375         0  I hate the fact that I'm genuinely excited abo...
# 2212063772         0  Tula's sick! Nausious, Nasal congestion, heada...
# 1557163971         0                           Hayfever time  not good!
# 1975133437         0  I wish diversity was like one of those musicia...
# 1932575931         0  Oh No - the Cavs lost game 4  Cavs are 1 loss ...
# 1467899025         0  still sick. feeling a bit better, got some new...
# 2324113552         0  worked on 5 bone marrow cases today! All + for...
# 1468042132         0                          It was a sleepless night
# 1467985185         0             @d_castillo ugh, that's disconcerting
# 1980282216         0  forgot about my english coursework &amp; my ip...
# 2179698078         0            @TweetRamona too bad it's in seattle..
# 1467985259         0                     MY TWEETS ARENT GOING THROUGH
# 2299794306         0  @SeattleRealEst8 439 calories; 28 grams of fat...
# ...              ...                                                ...
# 2194433506         0  I'm tweetless without miPhone   can't wait for...
# 1978986441         0  after seeing Ronan's latest update : I wish I ...
# 1467912100         0  @carolrainbow no Internet at home, have to dri...
# 1467872759         0  im lonely  keep me company! 22 female, california
# 1932409653         0             Damn the cavs lost I lost sum chippaz
# 1982476349         0  Can't finish my damn homework. Fifty more ques...
# 1467858627         0  Just woke up an already have written some e-ma...
# 2199414669         0        Got a fever, and this ain't the disco kind
# 2013743788         0  @leehopkins ok you guys are just too adorable!...
# 2241033723         0  I really want an iPhone, but I have to pay a f...
# 1795305046         0  @michelletripp Don't be too bummed. Saw it @ I...
# 1467910986         0  Keeping my fingers crossed for my buddy    He ...
# 1468038099         0  @sudam08  yes, someone hasn't been reading my ...
# 2053385413         0  I miss him so much  sosososo much. I wanna be ...
# 2000663077         0  Just waking up feeling really tired. Does hayf...
# 1467879203         0  I just saw that they found that Tracy girl in ...
# 2057515232         0    watching uruguay-brazil.. we need a miracle...
# 1754305167         0  @kevinprince I couldn't buy any '#openhacklond...
# 2209465938         0  @simondoggett I would like to install iphone 3...
# 1880171965         0  Just realised I have @hueyyei 's psp in my bag...
# 2214025188         0  I hope Microsoft have fixed #xboxlive #marketp...
# 1467986976         0  @georgeruiz Unfortunately one of those moments...
# 1752634162         0  @BleuMuze  Hit up gameworks and a movie in dow...
# 1467871661         0  I miss you twitter. My phone broke, now I'm us...
# 2071726448         0  @iLoveLyci lol i said the CAVS deserve to be i...
# 1468049681         0  A king sized bed is nice but sad and lonely wi...
# 2195475499         0  @breannalovesjb hurry up home!!!!! im dying wi...
# 1996172176         0  @jordanhowell lol only a PSP, had a game boy b...
# 2016105580         4  Good morning everyone!  It is such a beautiful...
# 2186977170         4  hey guess was @magicmanil the Lakers won and K...
#
# [2034 rows x 2 columns]

# %%
vectorizer.get_feature_names()
# Out:
# [u'00',
#  u'00 am',
#  u'00 m33',
#  u'000',
#  u'000 at',
#  u'000 followers',
#  u'000gbp',
#  u'000gbp for',
#  u'00am',
#  u'00am little',
#  u'06',
#  u'06 17',
#  u'06 38',
#  u'06h8t',
#  u'08tv6',
#  u'09',
#  u'09 is',
#  u'0gb',
#  u'0gb left',
#  u'10',
#  u'10 another',
#  u'10 cancer',
#  u'10 days',
#  u'10 hehe',
#  u'10 on',
#  u'10 that',
#  u'100',
#  u'100 000',
#  u'100 after',
#  u'100 followers',
#  u'100 on',
#  u'100 people',
#  u'100 votes',
#  u'101',
#  u'101 fever',
#  u'101 one',
#  u'101 riddled',
#  u'102',
#  u'102 fever',
#  u'103',
#  u'103 please',
#  u'10k',
#  u'10k and',
#  u'11',
#  u'11 and',
#  u'111',
#  u'111 followers',
#  u'11vcij',
#  u'12',
#  u'12 gym',
#  u'12 hours',
#  u'12 pages',
#  u'12 work',
#  u'1205308493',
#  u'1205308493 html',
#  u'123',
#  u'123 more',
#  u'12th',
#  u'13',
#  u'13 30',
#  u'13 and',
#  u'13 at',
#  u'130',
#  u'130 pics',
#  u'14',
#  u'14 amp',
#  u'14 year',
#  u'15',
#  u'15 about',
#  u'15 times',
#  u'15 where',
#  u'150',
#  u'150 on',
#  u'15th',
#  u'15th of',
#  u'16',
#  u'16 4th',
#  u'160',
#  u'16bolq',
#  u'16bolq ftsk',
#  u'16gb',
#  u'16gb 209',
#  u'16gb ipod',
#  u'17',
#  u'17nsud',
#  u'17nwof',
#  u'17th',
#  u'17th they',
#  u'1970s',
#  u'1970s quot',
#  u'19th',
#  u'19th crap',
#  u'1a7zpw',
#  u'1b',
#  u'1b still',
#  u'1pm',
#  u'1pm after',
#  u'1st',
#  u'1st birthday',
#  u'1st coffee',
#  u'1st full',
#  u'1st game',
#  u'1st page',
#  u'1st sydney',
#  u'1st win',
#  u'1vs100xboxlive',
#  u'1vs100xboxlive just',
#  u'1xtti',
#  u'20',
#  u'20 believe',
#  u'20 mins',
#  u'20 no',
#  u'20 pages',
#  u'200',
#  u'200 crunches',
#  u'2009',
#  u'2009 06',
#  u'2010',
#  u'2010 also',
#  u'2010 xboxe3',
#  u'209',
#  u'209 bloody',
#  u'20th',
#  u'20th of',
#  u'22',
#  u'22 female',
#  u'228',
#  u'228 people',
#  u'23',
#  u'23 slides',
#  u'23 vs',
#  u'231',
#  u'231 with',
#  u'24',
#  u'24 boring',
#  u'24 hours',
#  u'24 in',
#  u'24 pages',
#  u'24hrs',
#  u'24hrs here',
#  u'25',
#  u'25 1b',
#  u'25 pts',
#  u'25th',
#  u'260',
#  u'260 371',
#  u'28',
#  u'28 days',
#  u'28 grams',
#  u'28th',
#  u'28th follower',
#  u'29823782',
#  u'29823782 different',
#  u'2day',
#  u'2day fm',
#  u'2k9',
#  u'2k9 for',
#  u'2morrow',
#  u'2morrow will',
#  u'2nd',
#  u'2nd gen',
#  u'2nd shift',
#  u'2night',
#  u'2night could',
#  u'2nite',
#  u'2y36e',
#  u'2y36e cant',
#  u'2y5xp',
#  u'30',
#  u'30 000',
#  u'30 am',
#  u'30 and',
#  u'30 mins',
#  u'30 minutes',
#  u'30 on',
#  u'30 so',
#  u'3000',
#  u'3000 is',
#  u'3000 today',
#  u'301',
#  u'301 looking',
#  u'30am',
#  u'30am fuckin',
#  u'30comau',
#  u'30comau in',
#  u'30pm',
#  u'30pm im',
#  u'320',
#  u'320 more',
#  u'32gb',
#  u'32gb iphone',
#  u'33',
#  u'33 night',
#  u'33 please',
#  u'35',
#  u'35 headphones',
#  u'360',
#  u'360 http',
#  u'360 in',
#  u'360 news',
#  u'360 premiums',
#  u'360 rrod',
#  u'360 somebody',
#  u'360 to',
#  u'371',
#  u'371 followers',
#  u'38',
#  u'38 to',
#  u'395031',
#  u'395031 but',
#  u'39am',
#  u'39am getting',
#  u'3am',
#  u'3am mcdonalds',
#  u'3am still',
#  u'3d',
#  u'3d was',
#  u'3g',
#  u'3g still',
#  u'3g the',
#  u'3g to',
#  u'3g unboxing',
#  u'3gs',
#  u'3gs does',
#  u'3lzt1',
#  u'3lzt1 on',
#  u'3mk',
#  u'3rd',
#  u'3rd anniversary',
#  u'3rd degree',
#  u'3rd time',
#  u'3turnoffwords',
#  u'3turnoffwords quot',
#  u'3ve',
#  u'3ve taylor',
#  u'3yr',
#  u'3yr old',
#  u'3zgso',
#  u'3zgso very',
#  u'40',
#  u'40 am',
#  u'400',
#  u'400 quid',
#  u'404',
#  u'404 great',
#  u'41',
#  u'41 carbs',
#  u'42',
#  u'42 oouuuch',
#  u'420',
#  u'420 laws',
#  u'439',
#  u'439 calories',
#  u'447',
#  u'45',
#  u'45 man',
#  u'48',
#  u'48 hours',
#  u'49',
#  u'49 lbs',
#  u'4am',
#  u'4am woo',
#  u'4pm',
#  u'4pm now',
#  u'4th',
#  u'4th quarter',
#  u'4th trip',
#  u'50',
#  u'50 sng',
#  u'51am',
#  u'51am in',
#  u'5248435',
#  u'530',
#  u'530 am',
#  u'536',
#  u'536 page',
#  u'56m0y',
#  u'56m0y really',
#  u'57',
#  u'57 cents',
#  u'58',
#  u'58 00',
#  u'59',
#  u'5am',
#  u'5am it',
#  u'5am on',
#  u'5c9gs',
#  u'5c9gs picture',
#  u'5oh7',
#  u'5oh7 is',
#  u'5oll7',
#  u'5oll7 we',
#  u'5pm',
#  u'5pm so',
#  u'5th',
#  u'5th june',
#  u'5yr',
#  u'5yr old',
#  u'5\xba',
#  u'5\xba celsius',
#  u'62',
#  u'62 http',
#  u'62 spokesman',
#  u'640km',
#  u'640km northeast',
#  u'642',
#  u'6am',
#  u'6am and',
#  u'6am flight',
#  u'6idya',
#  u'6jw9f',
#  u'6q1om',
#  u'6q1om omg',
#  u'6r413',
#  u'6r413 on',
#  u'6ubr9',
#  u'6ubr9 woooho',
#  u'6vb49',
#  u'6vb49 wow',
#  u'70s',
#  u'70s waiting',
#  u'72',
#  u'74',
#  u'74 error',
#  u'74 nd',
#  u'75',
#  u'75 spent',
#  u'7e01t',
#  u'7e01t ahh',
#  u'7gteh',
#  u'7gteh not',
#  u'7gu8a',
#  u'7gu8a hav',
#  u'7hr45mins',
#  u'7hr45mins and',
#  u'7mki1',
#  u'7pf62',
#  u'7pf62 not',
#  u'7pm',
#  u'7pm in',
#  u'7w83x',
#  u'85',
#  u'85 degree',
#  u'8gb',
#  u'8gb ipod',
#  u'8gb memory',
#  u'8gb microsd',
#  u'8th',
#  u'8th looking',
#  u'8th year',
#  u'8yr',
#  u'8yr old',
#  u'96',
#  u'96 degrees',
#  u'96 male',
#  u'98',
#  u'98 hard',
#  u'98 yrs',
#  u'9am',
#  u'9am yesterday',
#  u'9th',
#  u'9th isn',
#  u'__',
#  u'__ missed',
#  u'__________',
#  u'__________ fill',
#  u'_chelsea_marie',
#  u'_chelsea_marie does',
#  u'_despina',
#  u'_despina my',
#  u'_myana',
#  u'_myana lt',
#  u'aaaaahhhh',
#  u'aaaaahhhh finally',
#  u'ab3dj',
#  u'ab3dj poor',
#  u'abandoning',
#  u'abandoning capitalism',
#  u'abbie',
#  u'abbie then',
#  u'abc',
#  u'abc action',
#  u'abi',
#  u'abi celebrating',
#  u'able',
#  u'able to',
#  u'about',
#  u'about 100',
#  u'about 20th',
#  u'about being',
#  u'about benny',
#  u'about buying',
#  u'about chile',
#  u'about die',
#  u'about england',
#  u'about facebook',
#  u'about farrah',
#  u'about following',
#  u'about gl',
#  u'about golden',
#  u'about him',
#  u'about his',
#  u'about hour',
#  u'about hours',
#  u'about innocent',
#  u'about iran',
#  u'about is',
#  u'about it',
#  u'about jordan',
#  u'about just',
#  u'about keeping',
#  u'about kutner',
#  u'about lack',
#  u'about lastnites',
#  u'about lebron',
#  u'about lilo',
#  u'about me',
#  u'about mr',
#  u'about my',
#  u'about nasal',
#  u'about night',
#  u'about no',
#  u'about now',
#  u'about oprah',
#  u'about quot',
#  u'about reese',
#  u'about seattle',
#  u'about supa',
#  u'about that',
#  u'about the',
#  u'about them',
#  u'about this',
#  u'about time',
#  u'about to',
#  u'about tori',
#  u'about twitter',
#  u'about ur',
#  u'about us',
#  u'about we',
#  u'about xbox',
#  u'about xyzall',
#  u'about you',
#  u'about your',
#  u'above',
#  u'above such',
#  u'absolutely',
#  u'absolutely loved',
#  u'absolutely loving',
#  u'absolutely nothing',
#  u'absoluty',
#  u'absoluty shut',
#  u'abt',
#  u'abt kobe',
#  u'abt sweet',
#  u'abu',
#  u'abu ghraib',
#  u'abusing',
#  u'abusing it',
#  u'ac',
#  u'ac home',
#  u'acacia_scott',
#  u'acacia_scott amp',
#  u'accent',
#  u'accent sucks',
#  u'accept',
#  u'accept defeat',
#  u'accept my',
#  u'accept the',
#  u'accessing',
#  u'accessing ttb',
#  u'accident',
#  u'accident quot',
#  u'accidental',
#  u'accidental clicks',
#  u'accidentally',
#  u'accidentally deleted',
#  u'accommodation',
#  u'accommodation to',
#  u'account',
#  u'account it',
#  u'account on',
#  u'account suspended',
#  u'ache',
#  u'ache and',
#  u'aches',
#  u'aches and',
#  u'achmed',
#  u'achmed the',
#  u'across',
#  u'across my',
#  u'act',
#  u'act for',
#  u'acting',
#  u'acting up',
#  u'action',
#  u'action at',
#  u'action news',
#  u'action seqs',
#  u'activated',
#  u'activated it',
#  u'activation',
#  u'activation server',
#  u'activation service',
#  u'actor',
#  u'actress',
#  u'actress farrah',
#  u'actual',
#  u'actual made',
#  u'actually',
#  u'actually always',
#  u'actually had',
#  u'actually the',
#  u'actually watch',
#  u'actually won',
#  u'ad',
#  u'ad campaign',
#  u'ad rip',
#  u'adams',
#  u'adamschwabe',
#  u'adawiyah',
#  u'adawiyah is',
#  u'add',
#  u'add me',
#  u'add music',
#  u'add prayers',
#  u'add sunisa',
#  u'add you',
#  u'addict',
#  u'addict and',
#  u'addicted',
#  u'addicted to',
#  u'adding',
#  u'adding me',
#  u'adding some',
#  u'adelaide',
#  u'adelaide no',
#  u'adeline_sky',
#  u'adeline_sky that',
#  u'adorable',
#  u'adorable month',
#  u'adorable you',
#  u'adrianogarcia',
#  u'adrianogarcia ok',
#  u'ads',
#  u'ads suck',
#  u'advance',
#  u'advance lol',
#  u'advance phone',
#  u'advance to',
#  u'advanced',
#  u'advanced tv',
#  u'advantage',
#  u'advantage of',
#  u'adventure',
#  u'adventure day',
#  u'advice',
#  u'advice on',
#  u'aerius',
#  u'aerius or',
#  u'afcrash',
#  u'afcrash took',
#  u'affected',
#  u'affected my',
#  u'affection',
#  u'affection from',
#  u'affliction',
#  u'affliction getaway',
#  u'afford',
#  u'afford an',
#  u'afford it',
#  u'afford miley',
#  u'afford one',
#  u'afford to',
#  u'afraid',
#  u'afraid if',
#  u'afrin',
#  u'afrin nasal',
#  u'after',
#  u'after 24',
#  u'after all',
#  u'after an',
#  u'after big',
#  u'after brilliant',
#  u'after cavs',
#  u'after cleaning',
#  u'after eating',
#  u'after gay',
#  u'after having',
#  u'after horses',
#  u'after last',
#  u'after late',
#  u'after long',
#  u'after losing',
#  u'after night',
#  u'after seeing',
#  u'after she',
#  u'after signed',
#  u'after the',
#  u'after used',
#  u'after warm',
#  u'after watching',
#  u'after we',
#  u'after work',
#  u'afternoon',
#  u'afternoon and',
#  u'afternoon in',
#  u'afternoon twerts',
#  u'afternoon while',
#  u'again',
#  u'again all',
#  u'again another',
#  u'again at',
#  u'again before',
#  u'again bluhhh',
#  u'again boarding',
#  u'again but',
#  u'again due',
#  u'again from',
#  u'again got',
#  u'again here',
#  u'again may',
#  u'again need',
#  u'again omg',
#  u'again or',
#  u'again outta',
#  u'again reset',
#  u'again subway',
#  u'again taking',
#  u'again they',
#  u'again today',
#  u'again two',
#  u'again ve',
#  u'again vegas',
#  u'against',
#  u'against the',
#  u'against tired',
#  u'against we',
#  u'agallerylondon',
#  u'agallerylondon hi',
#  u'age',
#  u'age 62',
#  u'age catching',
#  u'aged',
#  u'aged 62',
#  u'ages',
#  u'ages and',
#  u'ages now',
#  u'ago',
#  u'ago didya',
#  u'ago golakers',
#  u'ago pc',
#  u'ago the',
#  u'ago to',
#  u'ago too',
#  u'agree',
#  u'agree guess',
#  u'agreed',
#  u'agreed with',
#  u'ah',
#  u'ah see',
#  u'ah shit',
#  u'ah so',
#  u'ah well',
#  u'ahahaha',
#  u'ahaulil',
#  u'ahaulil have',
#  u'ahead',
#  u'ahead hope',
#  u'ahem',
#  u'ahem think',
#  u'ahh',
#  u'ahh kinda',
#  u'ahh love',
#  u'ahh ve',
#  u'ahh wish',
#  u'ahhh',
#  u'ahhh alright',
#  u'ahhh shiner',
#  u'ahhhghhh',
#  u'ahhhghhh they',
#  u'ahhhh',
#  u'ahhhh time',
#  u'ahhhhhh',
#  u'ahhhhhh guess',
#  u'ahmedinejad',
#  u'ahmedinejad supporters',
#  u'ahuhuhu',
#  u'aids',
#  u'aids orphans',
#  u'aierra',
#  u'aierra missing',
#  u'aim',
#  u'aim messages',
#  u'aim now',
#  u'aims7',
#  u'aims7 alirushton',
#  u'ain',
#  u'ain fun',
#  u'ain got',
#  u'ain happening',
#  u'ain the',
#  u'air',
#  u'air card',
#  u'air crash',
#  u'air france',
#  u'air haha',
#  u'air mattress',
#  u'air today',
#  u'airborne',
#  u'airborne did',
#  u'aircraft',
#  u'aircraft from',
#  u'airport',
#  u'airport for',
#  u'airport getting',
#  u'airport in',
#  u'airport is',
#  u'aj',
#  u'aka',
#  u'aka cuzin',
#  u'aka the',
#  u'akivafever',
#  u'akivafever sorry',
#  u'ako',
#  u'ako sa',
#  u'alabama',
#  u'alabama being',
#  u'alanasachi',
#  u'alanasachi hahaha',
#  u'alarm',
#  u'alarm clock',
#  u'alas',
#  u'alas nothing',
#  u'alaska',
#  u'album',
#  u'album has',
#  u'album in',
#  u'album is',
#  u'album lol',
#  u'album she',
#  u'albums',
#  u'albums like',
#  u'alex',
#  u'alex who',
#  u'alex_jeffreys',
#  u'alex_jeffreys welcome',
#  u'alexalltimelow',
#  u'alexalltimelow have',
#  u'alexalltimelow sydney',
#  u'alexalltimelow thankyou',
#  u'alexbigman',
#  u'alexbigman you',
#  u'algarcia3505',
#  u'algarcia3505 amp',
#  u'alibartlett',
#  u'alibartlett yeh',
#  u'alicayaba',
#  u'alicayaba so',
#  u'alielayus',
#  u'alielayus want',
#  u'aliens',
#  u'aliens in',
#  u'alikes',
#  u'alikes it',
#  u'alirushton',
#  u'alirushton dillyh',
#  u'alison',
#  u'alison says',
#  u'alittle',
#  u'alittle better',
#  u'alive',
#  u'alive and',
#  u'alive from',
#  u'alix_says',
#  u'alix_says it',
#  u'all',
#  u'all about',
#  u'all alone',
#  u'all are',
#  u'all back',
#  u'all be',
#  u'all blur',
#  u'all but',
#  u'all come',
#  u'all contacts',
#  u'all crummy',
#  u'all day',
#  u'all defense',
#  u'all depressd',
#  u'all diners',
#  u'all drano',
#  u'all ended',
#  u'all even',
#  u'all fierce',
#  u'all followers',
#  u'all for',
#  u'all get',
#  u'all gone',
#  u'all good',
#  u'all gotta',
#  u'all had',
#  u'all hail',
#  u'all have',
#  u'all his',
#  u'all hours',
#  u'all hype',
#  u'all im',
#  u'all in',
#  u'all iphone',
#  u'all is',
#  u'all it',
#  u'all kinds',
#  u'all late',
#  u'all let',
#  u'all lucky',
#  u'all man',
#  u'all musicians',
#  u'all my',
#  u'all networking',
#  u'all night',
#  u'all nighter',
#  u'all obama',
#  u'all of',
#  u'all off',
#  u'all orders',
#  u'all our',
#  u'all over',
#  u'all preparation',
#  u'all pretty',
#  u'all ready',
#  u'all rockstars',
#  u'all say',
#  u'all says',
#  u'all see',
#  u'all sweet',
#  u'all that',
#  u'all the',
#  u'all these',
#  u'all they',
#  u'all this',
#  u'all tied',
#  u'all time',
#  u'all times',
#  u'all to',
#  u'all types',
#  u'all up',
#  u'all want',
#  u'all wanted',
#  u'all weeks',
#  u'all went',
#  u'all your',
#  u'allen',
#  u'allen verfolgern',
#  u'allerfre',
#  u'allerfre who',
#  u'allergic',
#  u'allergic to',
#  u'allergies',
#  u'allergies sucks',
#  u'alliance',
#  u'alliance on',
#  u'allow',
#  u'allow me',
#  u'allowed',
#  u'allowed mcdonalds',
#  u'allowed stupid',
#  u'allowed to',
#  u'allows',
#  u'allows me',
#  u'allows only',
#  u'allthingsfresh',
#  u'allthingsfresh beautiful',
#  u'allyheman',
#  u'allyheman but',
#  u'almost',
#  u'almost 48',
#  u'almost freaking',
#  u'almost good',
#  u'almost home',
#  u'almost jumped',
#  u'almost months',
#  u'almost over',
#  u'almost times',
#  u'alone',
#  u'alone again',
#  u'alone because',
#  u'alone cause',
#  u'alone hello',
#  u'alone on',
#  u'along',
#  u'along with',
#  u'alot',
#  u'alot of',
#  u'already',
#  u'already damn',
#  u'already find',
#  u'already fuckin',
#  u'already gone',
#  u'already have',
#  u'already in',
#  u'already listened',
#  u'already miss',
#  u'already missing',
#  u'already nipping',
#  u'already stole',
#  u'already stringy',
#  u'already want',
#  u'already what',
#  u'alright',
#  u'alright thanks',
#  u'also',
#  u'also awaiting',
#  u'also be',
#  u'also details',
#  u'also failed',
#  u'also got',
#  u'also have',
#  u'also in',
#  u'also it',
#  u'also mcm',
#  u'also officially',
#  u'also pray',
#  u'also quite',
#  u'also sooooo',
#  u'also use',
#  u'also very',
#  u'also wayyy',
#  u'also why',
#  u'also win',
#  u'also won',
#  u'altho',
#  u'altho feel',
#  u'although',
#  u'although they',
#  u'although was',
#  u'always',
#  u'always awsome',
#  u'always be',
#  u'always brazil',
#  u'always cold',
#  u'always dead',
#  u'always from',
#  u'always have',
#  u'always in',
#  u'always makes',
#  u'always marjorie',
#  u'always open',
#  u'always rain',
#  u'always really',
#  u'always sad',
#  u'always sydney',
#  u'always that',
#  u'always the',
#  u'always there',
#  u'always wanted',
#  u'always warm',
#  u'always wonder',
#  u'aly',
#  u'aly amp',
#  u'alydesigns',
#  u'alydesigns was',
#  u'am',
#  u'am about',
#  u'am at',
#  u'am bored',
#  u'am curious',
#  u'am currently',
#  u'am dehydrated',
#  u'am devastated',
#  u'am doing',
#  u'am feeding',
#  u'am feelin',
#  u'am gettin',
#  u'am glad',
#  u'am going',
#  u'am grateful',
#  u'am heckling',
#  u'am hot',
#  u'am in',
#  u'am listing',
#  u'am living',
#  u'am lol',
#  u'am not',
#  u'am off',
#  u'am officially',
#  u'am over',
#  u'am rooting',
#  u'am sad',
#  u'am seriously',
#  u'am so',
#  u'am sooo',
#  u'am sorry',
#  u'am starving',
#  u'am still',
#  u'am stuck',
#  u'am suffering',
#  u'am supposed',
#  u'am the',
#  u'am this',
#  u'am tiff',
#  ...]

# %%
vectorizer.strip_accents()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-5d7c4cb641aa> in <module>()
# ----> 1 vectorizer.strip_accents()
#
# TypeError: 'NoneType' object is not callable

# %%
vectorizer.stop_words([it])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-2fb0031fd35f> in <module>()
# ----> 1 vectorizer.stop_words([it])
#
# NameError: name 'it' is not defined
